# %%
#import libraries
import numpy as np                
import pandas as pd

# %%
#load csv file
DataCo = pd.read_csv("DataCoSupplyChainDataset.csv",encoding = "latin")

# %%
DataCo.head(10)
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
# 5  TRANSFER                         6                              4
# 6     DEBIT                         2                              1
# 7  TRANSFER                         2                              1
# 8      CASH                         3                              2
# 9      CASH                         2                              1
#
#    Benefit per order  Sales per customer    Delivery Status  \
# 0          91.250000          314.640015   Advance shipping
# 1        -249.089996          311.359985      Late delivery
# ...
